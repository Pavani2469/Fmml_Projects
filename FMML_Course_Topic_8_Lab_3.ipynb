# %% [markdown]
# <a href="https://colab.research.google.com/github/Pavani2469/Fmml_Projects/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 08:24:58--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   195MB/s    in 0.4s
#
# 2024-03-31 08:24:59 (195 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 29296  1709.00308v2  In recent years, deep learning (DL), a re-bran...    cs
# 22038   1312.7604v2  Archetypal analysis represents a set of observ...  stat
# 6956   1708.01960v1  Distributed learning is an effective way to an...    cs
# 2047    1210.4918v1  We describe theoretical bounds and a practical...    cs
# 5629   1505.02870v1  We give a new consistent scoring function for ...    cs
# ...             ...                                                ...   ...
# 23546   1304.7211v1  We investigate possibilities to speed up itera...    cs
# 21743   1406.3469v4  We propose LOCO, an algorithm for large-scale ...  stat
# 28961  1708.01311v1  This paper proposes an automatic spatially-awa...    cs
# 22954  1711.08374v1  In this paper, a scale mixture of Normal distr...  stat
# 22265  1511.00831v1  Dimensionality reduction methods are very comm...  stat
#
#                                                    title  year  \
# 29296  A Comprehensive Survey of Deep Learning in Rem...  2017
# 22038                  Probabilistic Archetypal Analysis  2013
# 6956   Learning Theory of Distributed Regression with...  2017
# 2047   Dynamic Teaching in Sequential Decision Making...  2012
# 5629   Incorporating Type II Error Probabilities from...  2015
# ...                                                  ...   ...
# 23546  Algorithmic Optimisations for Iterative Deconv...  2013
# 21743  LOCO: Distributing Ridge Regression with Rando...  2014
# 28961  Automatic Spatially-aware Fashion Concept Disc...  2017
# 22954  Variational Bayesian Inference For A Scale Mix...  2017
# 22265  PCA-Based Out-of-Sample Extension for Dimensio...  2015
#
#                                                 keywords
# 29296  [recognition, processing, possesses, challenge...
# 22038  [archetypal, represents, observations, combina...
# 6956   [distributed, effective, distributed, regressi...
# 2047   [theoretical, practical, algorithm, demonstrat...
# 5629   [consistent, structure, traditional, approache...
# ...                                                  ...
# 23546  [investigate, possibilities, iterative, algori...
# 21743  [algorithm, regression, distributes, important...
# 28961  [automatic, spatially, discovery, googlenet, c...
# 22954  [distributions, developed, classification, clu...
# 22265  [dimensionality, reduction, dimensional, typic...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 29296    [recognition, processing, possesses, challenge...
# 22038    [archetypal, represents, observations, combina...
# 6956     [distributed, effective, distributed, regressi...
# 2047     [theoretical, practical, algorithm, demonstrat...
# 5629     [consistent, structure, traditional, approache...
#                                ...
# 8995     [marketing, propagating, conventional, adverti...
# 1824     [information, standards, predicting, trajector...
# 23551    [inpainting, predicting, inpainting, consuming...
# 31645    [detection, continuity, detection, importance,...
# 18998    [decisions, processes, increasing, theoretic, ...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8897 words.
# Out of those 4606 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="306e5b88-d13d-47b7-84fc-1a49c04a8907" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("306e5b88-d13d-47b7-84fc-1a49c04a8907")) {                    Plotly.newPlot(                        "306e5b88-d13d-47b7-84fc-1a49c04a8907",                        [{"x":["comprehensive","primarily","processing","understandable","architectures","challenges","recognition","possesses","inevitably","phenomena","inadequate","statistics","optimizing","heterogeneous","algorithms","theoretical","traditional","modelling","community","advancements","applications","opportunities","solutions","understanding","developments","specifically","framework","combinations","accommodates","summarize","principles","observation","situations","observations","corroborate","practical","methodology","probabilistic","compatible","geometric","countries","unfortunately","frequency","represents","archetypal","approximating","probability","convincing","formulation","visualization","archetypes","appropriate","nonlinear","effective","functions","corrected","regression","algorithm","regularization","performance","investigate","correction","conditions","distributed","sequences","demonstration","environment","supervised","dimension","extending","important","dynamically","sequential","previously","learnability","protocols","encountered","environments","optimized","frameworks","demonstrate","different","increases","generating","maximizing","precomputation","computation","distribution","independence","guaranteed","explanation","implementation","particularly","empirical","consistent","structure","complexity","approaches","distinguishes","computationally","conditional","tabulation","programming","probabilities","correctly","incorporating","polynomial","necessary","dependent","relaxation","translated","relatively","beneficial","scenarios","illustrate","exploitation","exploration","temporally","processes","reinforcement","significantly","primitive","stationary","piecewise","knowledge","factorization","ambiguities","available","constructed","biological","interactions","uniqueness","developed","factorizations","directional","simulated","unobservable","pervasive","inference","variables","conventional","properties","operation","decomposition","exogenous","underlying","capitalizing","financial","reasonably","measurable","decompositions","microblogs","advocates","structures","identification","generally","extensive","facilitate","identifying","structural","topologies","revealing","analytics","engineered","dimensions","magnitude","analytically","empirically","constitutes","comparing","detecting","relationship","naturally","likelihood","distributions","intrinsic","symmetric","multivariate","detection","detectability","difficulty","investigated","effectiveness","divergence","particular","challenging","efficient","techniques","formation","illumination","automatically","quantitative","estimation","representations","integration","segmentation","perceptual","parameters","rendering","separation"],"y":[58,18,283,4,127,130,384,6,6,21,6,67,49,36,609,169,162,48,63,12,412,17,150,157,22,170,543,37,2,15,31,59,45,68,5,132,65,147,13,59,8,33,52,48,1,14,183,5,71,26,0,83,53,262,213,13,126,802,89,892,143,31,140,104,95,17,126,214,67,39,375,32,67,100,4,14,17,86,61,38,550,775,44,90,24,2,131,212,31,36,24,131,72,154,98,364,233,466,4,99,95,2,107,65,37,61,64,84,82,20,17,63,28,100,75,14,54,19,94,112,241,14,24,20,327,45,6,299,67,44,75,7,192,1,15,65,2,4,200,144,114,241,40,62,1,121,5,17,11,1,10,2,3,127,104,66,178,46,75,72,6,6,17,10,40,61,15,74,10,80,72,64,60,51,117,54,25,27,348,0,41,52,210,25,296,262,429,381,21,40,199,68,213,240,44,220,28,244,17,32],"type":"bar"},{"x":["comprehensive","primarily","processing","unders ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4606,), (4606, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8075

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>the</span> <span style=''>monotonization</span> <span style=''>of</span> <span style=''>the</span> <span style=''>training</span> <span style=''>set</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>minimal</span> <span style='background-color:rgba(0, 255, 0, 0.40909090909090917);'>correction</span> <span style=''>of</span> <span style=''>the</span> <span style=''>training</span> <span style=''>set</span> <span style=''>to</span> <span style=''>make</span> <span style=''>it</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistent</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>monotonic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>This</span> <span style=''>problem</span> <span style=''>arises</span> <span style=''>during</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>via</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>that</span> <span style=''>require</span> <span style=''>monotone</span> <span style=''>data</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>NP</span> <span style=''>hard</span> <span style=''>in</span> <span style=''>general</span> <span style=''>and</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equivalent</span> <span style=''>to</span> <span style=''>finding</span> <span style=''>a</span> <span style=''>maximal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independent</span> <span style=''>set</span> <span style=''>in</span> <span style=''>special</span> <span style=''>orgraphs</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Practically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>cases</span> <span style=''>of</span> <span style=''>that</span> <span style=''>problem</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considered</span> <span style=''>in</span> <span style=''>detail</span> <span style=''>These</span> <span style=''>are</span> <span style=''>the</span> <span style=''>cases</span> <span style=''>when</span> <span style=''>a</span> <span style=''>partial</span> <span style=''>order</span> <span style=''>given</span> <span style=''>on</span> <span style=''>the</span> <span style=''>replies</span> <span style=''>set</span> <span style=''>is</span> <span style=''>a</span> <span style=''>total</span> <span style=''>order</span> <span style=''>or</span> <span style=''>has</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.37383177570093457);'>dimension</span> <span style=''>2</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>second</span> <span style=''>case</span> <span style=''>can</span> <span style=''>be</span> <span style=''>reduced</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3793103448275861);'>maximization</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3012048192771084);'>quadratic</span> <span style=''>convex</span> <span style=''>function</span> <span style=''>on</span> <span style=''>a</span> <span style=''>convex</span> <span style=''>set</span> <span style=''>For</span> <span style=''>this</span> <span style=''>case</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>construct</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style='background-color:rgba(0, 255, 0, 0.3); ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Noisy</span> <span style=''>Tensor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Completion</span> <span style=''>for</span> <span style=''>Tensors</span> <span style=''>with</span> <span style=''>a</span> <span style=''>Sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Canonical</span> <span style=''>Polyadic</span> <span style=''>Factor</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>study</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>noisy</span> <span style=''>tensor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>completion</span> <span style=''>for</span> <span style=''>tensors</span> <span style=''>that</span> <span style=''>admit</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>canonical</span> <span style=''>polyadic</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>CANDECOMPPARAFAC</span> <span style=''>(CP)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>with</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>factors</span> <span style=''>being</span> <span style=''>sparse</span> <span style=''>We</span> <span style=''>present</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>error</span> <span style=''>bounds</span> <span style=''>for</span> <span style=''>an</span> <span style=''>estimate</span> <span style=''>obtained</span> <span style=''>by</span> <span style=''>using</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularized</span> <span style=''>maximum</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>principle</span> <span style=''>and</span> <span style=''>then</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>instantiate</span> <span style=''>these</span> <span style=''>bounds</span> <span style=''>for</span> <span style=''>the</span> <span style=''>case</span> <span style=''>of</span> <span style=''>additive</span> <span style=''>white</span> <span style=''>Gaussian</span> <span style=''>noise</span> <span style=''>We</span> <span style=''>also</span> <span style=''>provide</span> <span style=''>an</span> <span style=''>ADMM</span> <span style=''>type</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>solving</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularized</span> <span style=''>maximum</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>problem</span> <span style=''>and</span> <span style=''>validate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>finding</span> <span style=''>via</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>synthetic</span> <span style=''>data</span> <span style=''>set</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Near</span> <span style=''>optimal</span> <span style=''>sample</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>for</span> <span style=''>convex</span> <span style=''>tensor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>completion</span> <br/><br/><span style=''>We</span> <span style=''>analyze</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>tensor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>completion</span> <span style=''>(TC)</span> <span style=''>using</span> <span style=''>noisy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurements</span> <span style=''>of</span> <span style=''>a</span> <span style=''>subset</span> <span style=''>of</span> <span style=''>the</span> <span style=''>tensor</span> <span style=''>Assuming</span> <span style=''>a</span> <span style=''>rank</span> <span style=''>r</span> <span style=''>order</span> <span style=''>d</span> <span style=''>N</span> <span style=''>times</span> <span style=''>N</span> <span style=''>times</span> <span style=''>cdots</span> <span style=''>times</span> <span style=''>N</span> <span style=''>tensor</span> <span style=''>where</span> <span style=''>rO(1)</span> <span style=''>the</span> <span style=''>best</span> <span style=''>sampling</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>that</span> <span style=''>was</span> <span style=''>achieved</span> <span style=''>is</span> <span style=''>O(Nfracd2)</span> <span style=''>which</span> <span style=''>is</span> <span style=''>obtained</span> <span style=''>by</span> <span style=''>solving</span> <span style=''>a</span> <span style=''>tensor</span> <span style=''>nuclear</span> <span style=''>norm</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>problem</span> <span style=''>However</span> <span style=''>this</span> <span style=''>bound</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>significantly</span> <span style=''>larger</span> <span style=''>than</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>free</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variables</span> <span style=''>in</span> <span style=''>a</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>tensor</span> <span style=''>which</span> <span style=''>is</span> <span style=''>O(dN)</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>by</span> <span style=''>using</span> <span style=''>an</span> <span style=''>atomic</span> <span style=''>norm</span> <span style=''>whose</span> <span style=''>atoms</span> <span style=''>are</span> <span style=''>rank</span> <span style=''>1</span> <span style=''>sign</span> <span style=''>tensors</span> <span style=''>one</span> <span style=''>can</span> <span style=''>obtain</span> <span style=''>a</span> <span style=''>sample</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>of</span> <span style=''>O(dN)</span> <span style=''>Moreover</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalize</span> <span style=''>the</span> <span style=''>matrix</span> <span style=''>max</span> <span style=''>norm</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>definition</span> <span style=''>to</span> <span style=''>tensors</span> <span style=''>which</span> <span style=''>results</span> <span style=''>in</span> <span style=''>a</span> <span style=''>max</span> <span style=''>quasi</span> <span style=''>norm</span> <span style=''>(max</span> <span style=''>qnorm)</span> <span style=''>whose</span> <span style=''>unit</span> <span style=''>ball</span> <span style=''>has</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Optimal</span> <span style=''>Low</span> <span style=''>Rank</span> <span style=''>Tensor</span> <span style=''>Recovery</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Separable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Measurements</span> <span style=''>Four</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Contractions</span> <span style=''>Suffice</span> <br/><br/><span style=''>Tensors</span> <span style=''>play</span> <span style=''>a</span> <span style=''>central</span> <span style=''>role</span> <span style=''>in</span> <span style=''>many</span> <span style=''>modern</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>and</span> <span style=''>signal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>In</span> <span style=''>such</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>the</span> <span style=''>target</span> <span style=''>tensor</span> <span style=''>is</span> <span style=''>usually</span> <span style=''>of</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>ie</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expressed</span> <span style=''>as</span> <span style=''>a</span> <span style=''>sum</span> <span style=''>of</span> <span style=''>a</span> <span style=''>small</span> <span style=''>number</span> <span style=''>of</span> <span style=''>rank</span> <span style=''>one</span> <span style=''>tensors</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>motivates</span> <span style=''>us</span> <span style=''>to</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>tensor</span> <span style=''>recovery</span> <span style=''>from</span> <span style=''>a</span> <span style=''>class</span> <span style=''>of</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>measurements</span> <span style=''>called</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>measurements</span> <span style=''>As</span> <span style=''>specific</span> <span style=''>examples</span> <span style=''>we</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>two</span> <span style=''>distinct</span> <span style=''>types</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>measurement</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>mechanisms</span> <span style=''>(a)</span> <span style=''>Random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projections</span> <span style=''>where</span> <span style=''>each</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>measurement</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponds</span> <span style=''>to</span> <span style=''>an</span> <span style=''>inner</span> <span style=''>product</span> <span style=''>of</span> <span style=''>the</span> <span style=''>tensor</span> <span style=''>with</span> <span style=''>a</span> <span style=''>suitable</span> <span style=''>random</span> <span style=''>tensor</span> <span style=''>and</span> <span style=''>(b)</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>completion</span> <span style=''>problem</span> <span style=''>where</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>measurements</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constitute</span> <span style='background-color:rgba(255, 0, 0, 0. ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.07717157214644652)
# 	processing (0.10157932519741565)
# 	information (0.24874371859296482)
# 	segmentation (0.07896625987078248)
# 	experimental (0.14860014357501794)
# 	representation (0.13783201722900215)
# 	detection (0.1249102656137832)
# 	convolutional (0.13747307968413497)
# 	recognition (0.13783201722900215)
# 	different (0.27817659727207467)
#
# Some Statistics words are:
# 	functions (0.15739821251241312)
# 	stochastic (0.13257199602780537)
# 	theoretical (0.15143992055610725)
# 	statistical (0.15342601787487586)
# 	estimation (0.17378351539225423)
# 	algorithm (0.3952333664349553)
# 	distribution (0.1906653426017875)
# 	regression (0.1628599801390268)
# 	dimensional (0.18123138033763656)
# 	inference (0.19463753723932473)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e776ecd4-2468-43e8-8ca0-7a688c5f32d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e776ecd4-2468-43e8-8ca0-7a688c5f32d3")) {                    Plotly.newPlot(                        "e776ecd4-2468-43e8-8ca0-7a688c5f32d3",                        [{"x":["comprehensive","primarily","processing","understandable","architectures","challenges","recognition","possesses","inevitably","phenomena","inadequate","statistics","optimizing","heterogeneous","algorithms","theoretical","traditional","modelling","community","advancements","applications","opportunities","solutions","understanding","developments","specifically","framework","combinations","accommodates","summarize","principles","observation","situations","observations","corroborate","practical","methodology","probabilistic","compatible","geometric","countries","unfortunately","frequency","represents","archetypal","approximating","probability","convincing","formulation","visualization","archetypes","appropriate","nonlinear","effective","functions","corrected","regression","algorithm","regularization","performance","investigate","correction","conditions","distributed","sequences","demonstration","environment","supervised","dimension","extending","important","dynamically","sequential","previously","learnability","protocols","encountered","environments","optimized","frameworks","demonstrate","different","increases","generating","maximizing","precomputation","computation","distribution","independence","guaranteed","explanation","implementation","particularly","empirical","consistent","structure","complexity","approaches","distinguishes","computationally","conditional","tabulation","programming","probabilities","correctly","incorporating","polynomial","necessary","dependent","relaxation","translated","relatively","beneficial","scenarios","illustrate","exploitation","exploration","temporally","processes","reinforcement","significantly","primitive","stationary","piecewise","knowledge","factorization","ambiguities","available","constructed","biological","interactions","uniqueness","developed","factorizations","directional","simulated","unobservable","pervasive","inference","variables","conventional","properties","operation","decomposition","exogenous","underlying","capitalizing","financial","reasonably","measurable","decompositions","microblogs","advocates","structures","identification","generally","extensive","facilitate","identifying","structural","topologies","revealing","analytics","engineered","dimensions","magnitude","analytically","empirically","constitutes","comparing","detecting","relationship","naturally","likelihood","distributions","intrinsic","symmetric","multivariate","detection","detectability","difficulty","investigated","effectiveness","divergence","particular","challenging","efficient","techniques","formation","illumination","automatically","quantitative","estimation","representations","integration","segmentation","perceptual","parameters","rendering","separation","convolutional","lambertian","foreground","intermediate","qualitative","translation","evaluation","deploying","strategies","increased","selection","guideline","diffusion","experimental","selectively","analytical","parameter","unregularized","expression","incorporation","computational","sensitive","reproduce","comparative","detectors","conclusions","threshold","benchmark","publications","alignment","synthetic","differences","contributions","sensitivity","comparison","description","intensively","retrained","following","suggestions","detections","thresholding","architecture","sparsifying","iterative","perfectly","interpretable","implicitly","correlated","dictionary","considered","recurrent","compressive", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	archetypes
# 	detectability
# 	cumulants
# 	nutrition
# 	concordance
# 	intracellular
# 	amortization
# 	deflation
# 	oscillates
# 	bernsteins
# 	nesterovs
# 	subtleties
# 	backfitting
# 	criticized
# 	equitability
# 	sequentialized
# 	quadratures
# 	overfitted
# 	transmitting
# 	illustrations
# Some words which never appear in Statistics papers:
# 	precomputation
# 	illumination
# 	lambertian
# 	retrained
# 	propositional
# 	quantifier
# 	nondeterministic
# 	inflexibility
# 	ultrasound
# 	trustworthy
# 	interdependencies
# 	perpetual
# 	deceptive
# 	contracts
# 	satellites
# 	axiomatization
# 	lotteries
# 	expressible
# 	elongated
# 	obstacles

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.080145382862071e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7616666666666667
